# %% [markdown]
# # Домашнее задание №1 - EDA. Уменьшение размерности

# %% [markdown]
# В этой домашке вам предстоит немножко углубиться в изучение **показателей крови**, а именно посмотреть по каким параметрам общего анализа крови ставится тот или иной **вид анемии**. Но не пугайтесь биологии, она тут необязательная :)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler # И другие скейлеры
from scipy import stats
from umap import UMAP
# И другие необходимые импорты

# %% [markdown]
# Мы будем использовать общедоступный датасет **Anemia Disease Dataset**.
# Любую работу в анализе данных стоит начинать с самостоятельного изучения этих самых данных, с которыми вам нужно поработать. Почитайте описание этого датасета по ссылкам ниже, поймите в каких колонках что представлено, какого характера данные в них должны быть (минимальное/максимальное значение, число или текст), сколько тут пациентов и есть ли какие-то тонкости относительно качества данных. Что есть признаки, а что есть таргет для будущих анализа и предсказаний.
#
# [Датасет на kaggle](https://www.kaggle.com/code/serhathoca/anemia-disease-dataset/notebook)
#
# [Публикация, из которой взят датасет](https://www.sciencedirect.com/science/article/abs/pii/S174680942030361X)
#
# Но помните: *Ушам своим не верьте вовсе, а глазам — только наполовину.* © «Убийство на улице Морг» Эдгар Аллан По.
#
# Так что даже если у вас есть супер-описание вашего нового датасета, то на вашей совести проверить эти данные перед работой (даже если его проверяли специалисты и эксперты). Делайте EDA, чтобы узнать что-то новое о данных!

# %% [markdown]
# ## Часть 0. Загружаем данные (10 баллов)

# %%
df = pd.read_csv('anemia_dataset.csv', index_col = 0)
df
# Out:
#       GENDER        WBC   NE#   LY#   MO#   EO#   BA#   RBC    HGB    HCT  \
# 0          1  10.630000  6.31  2.79  0.91  0.56  0.06  4.31  12.70  37.60
# 1          1   5.080000  2.50  1.87  0.43  0.26  0.02  4.34  12.80  36.90
# 2          1  13.680000  9.40  2.69  1.55  0.03  0.01  3.18   9.40  27.50
# 3          1   5.600000  3.94  0.83  0.54  0.26  0.03  3.35  10.50  31.40
# 4          1   3.570000  2.03  1.25  0.10  0.18  0.01  1.31   5.10  14.30
# ...      ...        ...   ...   ...   ...   ...   ...   ...    ...    ...
# 1420       1   9.550000  5.88  3.04  0.55  0.03  0.05  4.81  11.86  38.03
# 1421       0   8.436995  0.77  0.86  0.17  0.03  0.02  3.72   8.70  28.10
# 1422       0   7.180000  4.36  2.04  0.53  0.20  0.05  4.42  10.00  32.30
# 1423       0   4.020000  2.69  1.11  0.17  0.03  0.02  4.76  11.14  34.62
# 1424       1   8.970000  6.90  1.05   NaN  0.15  0.04  4.35  11.80  36.70
#
#       ...   SDTSD        TSD    FERRITTE  FOLATE     B12  All_Class  \
# ...

# %% [markdown]
# Как вы поняли, в датасете есть колонки, отвечающие за тип анемии (*anemia_class*) - приведите их к виду **"одна колонка с категорией пациента в виде строки"**, используя методы melt/pivot.
# > Использовать колонку *All_Class* запрещено.
#
# Почитать про [melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html).
# Почитать про [pivot](https://pandas.pydata.org/docs/reference/api/pandas.pivot.html).

# %%
#your code is here

# %% [markdown]
# Почистите датасет от **выбросов**, перед этим проверив их наличие.

# %%
#your code is here, if you want

# %% [markdown]
# Не забудьте **удалить** уже ненужные колонки.

# %%
#your code is here

# %% [markdown]
# ## Часть 1. Анализ числовых признаков (10 баллов)

# %% [markdown]
# Какие **числовые признаки** есть в этом датасете? И что они **означают**?

# %%
#your code is here

# %% [markdown]
# Найдите по одной переменной с **нормальным**, **лог-нормальным** и **мультимодальным** распределением. Приведите соответствующие **графики** и, в случае нормальности и лог-нормальности, докажите, что выборка распределена соответствующе.
#
# *Возможно, вам будет интересен модуль `scipy.stats`*

# %%
#your code is here

# %% [markdown]
# Для любого распределения переменной на ваш выбор сгенерируйте выборку, оцените его параметры (например, методом моментов или ММП), постройте новое распределение с найденными параметрами и проверьте его качество с помощью стат. теста.

# %%
#your code is here

# %% [markdown]
# **Доп. задание:** Если вы хорошо построите **график распределения** переменной `B12`, то увидите заметный **пик** в области больших значений. **Подумайте** откуда мог взяться этот пик.

# %%
#your answer code here, if you want

# %% [markdown]
# ## Часть 2. Анализ категориальных признаков (10 баллов)

# %% [markdown]
# Какие **категориальные признаки** есть в этом датасете? Они **порядковые** или **номинальные**?

# %%
#your code is here

# %% [markdown]
# Придумайте и добавьте в ваш датасет **два дополнительных порядковых** признака.

# %%
#your code is here

# %% [markdown]
# Убедитесь в **типах данных** каждого признака. Особенно обратите внимание на **порядковые**. Обычно это должны быть `pd.Categorical` с учётом упорядоченности.

# %%
#your code is here

# %% [markdown]
# Изобразите наглядные **боксплоты** для `B12` по одной из **категориальных** переменных. **Прокомментируйте** ваш результат.

# %%
#your code is here

# %% [markdown]
# ## Часть 3. Группируем данные и анализируем (10 баллов)

# %% [markdown]
# В датасете есть категориальная переменная `GENDER`. Определите все переменные, значение которых **зависит от пола**.
#
# Объясните как именно вы определяли зависимость.

# %%
#your code is here

# %% [markdown]
# В случае значимого отличия между группами **визуализируйте эти отличия** любым удобным и наглядным способом.
#
# **Доп. задание:** предложите биологическую интерпретацию значимых отличий.

# %%
#your code is here

# %% [markdown]
# ## Часть 4. Поиск взаимосвязей в данных: Корреляции и Хитмапы (10 баллов)

# %% [markdown]
# Для здоровых пациентов вычислите **корреляцию между числовыми признаками**. Какие пары признаков имеют **наибольший** коэффициент корреляции, а какие **наименьший**?
#
# **Доп. задание.** Попробуйте **порассуждать** почему именно так.

# %%
#your code is here

# %% [markdown]
# Постройте **heatmap**, в котором все попарно **не стат. значимые** корреляции будут отмечены **серым**, а **стат. значимые** цветом **в зависимости** от значения коэффициента корреляции.

# %%
#your code is here

# %% [markdown]
# В датасете есть **пара переменных с интересной зависимостью**. Найдите эту пару переменных, наглядно изобразите график. Какой коэффициент корреляции между этими переменными?
#
# **Доп. заданние.** сформируйте **биологическую гипотезу** о природе зависимости.

# %%
#your code is here

# %% [markdown]
# ## Часть 5. Уменьшение размерности: PCA (20 баллов)

# %% [markdown]
# Постройте **PCA** по числовым переменным для четырех версий датасета:
# * в исходном виде
# * с применением min-max стандартизации
# * с применением z-стандартизации
# * с применением robust стандартизации
#
# И не забудьте **визуализировать** результаты.

# %%
#your code is here

# %% [markdown]
# Посмотрите внимательно на изображения вариантов PCA. **Чем** они отличаются?

# %%
#your code is here

# %% [markdown]
# Выберите вариант, который на ваш взгляд, **лучший**. Объясните свой **выбор** и приведите **долю объясненной дисперсии** для первых 5 компонент. Постройте подобный **график** для ваших данных.

# %% [markdown]
# ![variance_pca](variance_pca.jpg)

# %%
#Получаем долю объяснённой дисперсии
explained_variance_ratio = pca.explained_variance_ratio_
explained_variance_cum = np.cumsum(explained_variance_ratio)

#your code is here

# %% [markdown]
# Какие переменные дают **наибольший вклад** в первую компоненту? А во вторую?

# %%
first_component = pca.components_[0]

#your code is here

# %% [markdown]
# **Разукрасьте** ваш лучший вариант по:
# * полу
# * диагнозу
# * статусу больной/здоровый
#
# **Прокомментируйте** то, что получилось.

# %%
#your code is here

# %% [markdown]
# ## Часть 6. Уменьшение размерности: t-SNE (15 баллов)

# %% [markdown]
# Постройте **t-SNE** по числовым переменным для одной из стандартизованных версий датасета. Объясните выбор версии.
#
# Посмотрите на разные значения параметра perplexity. Какой лучше всего подходит для вашего датасета?
#
# Если будет интересно, можно [почитать](https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf).

# %%
tsne = TSNE(perplexity='YOUR VALUE')
#your code is here

# %% [markdown]
# **Разукрасьте** ваш лучший вариант по:
# * полу
# * диагнозу
# * статусу больной/здоровый
#
# **Прокомментируйте** то, что получилось.

# %%
#your code is here

# %% [markdown]
# ## Часть 7. Уменьшение размерности: UMAP (15 баллов)

# %% [markdown]
# Постройте **UMAP** по числовым переменным для одной из стандартизованных версий датасета. Объясните выбор версии.
#
# Посмотрите на разные значения параметров min_dist и k_neighbors. Какие лучше всего подходят для вашего датасета?
#
# Если будет интересно, можно [почитать](https://arxiv.org/pdf/1802.03426).

# %%
umap = UMAP(n_neighbors='YOUR VALUE', min_dist='YOUR VALUE')
#your code is here

# %% [markdown]
# **Разукрасьте** ваш лучший вариант по:
# * полу
# * диагнозу
# * статусу больной/здоровый
#
# **Прокомментируйте** то, что получилось.

# %%
#your code is here

# %% [markdown]
# ## Часть 8. Фидбек

# %% [markdown]
# **Отлично! Вы дошли до конца второй домашки!**
#
# Поделитесь с нами вашими ощущениями об этой домашке. Сколько времени вы потратили? Что понравилось/не понравилось?
#
# Использовали ли вы нейросети для выполнения работы или делали полностью сами?
#
# Если использовали - помогает ли это понять или просто экономит время? Если не использовали - почему?

# %%
#that's your turn

# %% [markdown]
# ## Давайте знакомиться

# %% [markdown]
# Расскажите нам о вашем **питомце**, если он есть :)
#
# Если у вас нет питомца - расскажите про своё любимое животное!
#
# Картинки приветствуются!

# %%
#Meow
